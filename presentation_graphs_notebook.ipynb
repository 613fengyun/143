# %%
# Hello this is the notebook for Group 12: Connor Huang, Zeyu Li, Sahil Mehra, and Linxiao Xia
# From here we will show you how the code is run


'''

IMPORTANT NOTE: The graphs **WILL** be different from the presentation bc there is 1/200 times 
less rows in the dataset to let it fit inside of GitHub. Some categories like Fashion and Appliances
have very few row items to run off of. 

'''
# Out:
# '\n\nIMPORTANT NOTE:\n\n'

# %%
# First lets make sure we have all of our modules imported. 
# as of now we need the following:
# pandas, matplotlib, seaborn, nltk, wordcloud, numpy
# install all of those modules

# %%
# From here we can start importing our files

# %%
import sys
sys.path.insert(0,"./final_code")

import final_code.main as ms #ms for main script
import pandas as pd #3rd-party
import matplotlib.pyplot as plt #3rd-party
import seaborn as sns #3rd-party
import numpy as np #3rd-party
import os
import csv
import json
from collections import Counter
from wordcloud import WordCloud
import string
from nltk.corpus import stopwords  # Assuming NLTK is installed #3rd-party
import nltk #3rd-party
# %matplotlib inline

# %%
# File path and plots saving path
# Used as global vars
INPUT_CSV = "truncated_filtered_reviews.csv"
plots_directory = "temp_plots/"

# %%
ms.connor_main()
'''
Parsing for Verfied and total word counts across the entire dataset
'''
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Connor
# [nltk_data]     Huang\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
ms.zeyu_linxiao_main()

'''
Ratings, Price, and Category Comparisons
'''
# Out:
# h:\School Crap\WI 2024\ECE143\project-final\final_code\main.py:145: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Price Category', y='Rating', hue='Source Category', data=data, palette='coolwarm', ci=None)

# %%
ms.sahil_main()

'''
Part of per-category word analysis
'''
# Out:
# Starting with AMAZON_FASHION_5.json category
# Starting with Appliances_5.json category
# Starting with Electronics_5.json category
# Starting with Musical_Instruments_5.json category
# Starting with Office_Products_5.json category
# Starting with Toys_and_Games_5.json category
